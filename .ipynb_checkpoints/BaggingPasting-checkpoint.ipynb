# %%
import pandas as pd 

import matplotlib.pyplot as plt

# %%
insurance_data = pd.read_csv(r'C:\Users\Shaleen\Desktop\jpnb\DESIGNING\ensemble-NN-sol\2.0\insurance.csv')

insurance_data.sample(10)
# Out:
#       age     sex     bmi  children smoker     region      charges
# 63     28  female  25.935         1     no  northwest   4133.64165
# 961    29  female  25.900         0     no  southwest   3353.28400
# 422    40    male  32.775         1    yes  northeast  39125.33225
# 468    28  female  24.320         1     no  northeast  23288.92840
# 1135   50  female  28.120         3     no  northwest  11085.58680
# 44     38    male  37.050         1     no  northeast   6079.67150
# 691    47    male  36.200         1     no  southwest   8068.18500
# 1083   32    male  31.500         1     no  southwest   4076.49700
# 1044   55    male  35.245         1     no  northeast  11394.06555
# 379    62    male  31.460         1     no  southeast  27000.98473

# %%
insurance_data.shape
# Out:
# (1338, 7)

# %%
insurance_data_correlation = insurance_data.corr()

insurance_data_correlation
# Out:
#                age       bmi  children   charges
# age       1.000000  0.109272  0.042469  0.299008
# bmi       0.109272  1.000000  0.012759  0.198341
# children  0.042469  0.012759  1.000000  0.067998
# charges   0.299008  0.198341  0.067998  1.000000

# %%
import seaborn as sns
    
fig, ax =plt.subplots(figsize=(8, 8))

sns.heatmap(insurance_data_correlation, annot=True)

# %%
from sklearn import preprocessing

label_encoding = preprocessing.LabelEncoder()

# %%
insurance_data['region'] = label_encoding.fit_transform(insurance_data['region'].astype(str))

insurance_data.head()
# Out:
#    age     sex     bmi  children smoker  region      charges
# 0   19  female  27.900         0    yes       3  16884.92400
# 1   18    male  33.770         1     no       2   1725.55230
# 2   28    male  33.000         3     no       2   4449.46200
# 3   33    male  22.705         0     no       1  21984.47061
# 4   32    male  28.880         0     no       1   3866.85520

# %%
label_encoding.classes_
# Out:
# array(['northeast', 'northwest', 'southeast', 'southwest'], dtype=object)

# %%
#encode using one_hot_encoding
insurance_data = pd.get_dummies(insurance_data, columns=['sex',
                                                        'smoker'])

insurance_data.sample(10)
# Out:
#       age     bmi  children  region      charges  sex_female  sex_male  \
# 1115   55  32.670         1       2  10807.48630           0         1
# 640    33  42.400         5       3   6666.24300           0         1
# 1152   43  32.560         3       2  40941.28540           1         0
# 1332   52  44.700         3       3  11411.68500           1         0
# 577    31  38.095         1       0  58571.07448           1         0
# 225    55  33.880         3       2  11987.16820           0         1
# 281    54  40.565         3       0  48549.17835           0         1
# 179    41  33.155         3       0   8538.28845           1         0
# 1294   58  25.175         0       0  11931.12525           0         1
# 401    47  47.520         1       2   8083.91980           0         1
#
#       smoker_no  smoker_yes
# 1115          1           0
# 640           1           0
# 1152          0           1
# 1332          1           0
# 577           0           1
# ...

# %%
insurance_data.to_csv(r'C:\Users\Shaleen\Desktop\jpnb\DESIGNING\ensemble-NN-sol\2.0\insurance_processed.csv')

# %%
insurance_data = pd.read_csv(r'C:\Users\Shaleen\Desktop\jpnb\DESIGNING\ensemble-NN-sol\2.0\insurance_processed.csv')

insurance_data.sample(10)
# Out:
#       Unnamed: 0  age     bmi  children  region      charges  sex_female  \
# 24            24   37  28.025         2       1   6203.90175           0
# 885          885   32  28.930         1       2  19719.69470           0
# 1163        1163   18  28.215         0       0   2200.83085           1
# 822          822   18  31.130         0       2   1621.88270           1
# 1035        1035   54  23.000         3       3  12094.47800           1
# 694          694   27  34.800         1       3   3577.99900           1
# 815          815   20  31.460         0       2   1877.92940           1
# 794          794   39  31.920         2       1   7209.49180           1
# 945          945   56  35.800         1       3  11674.13000           1
# 672          672   36  29.700         0       2   4399.73100           0
#
#       sex_male  smoker_no  smoker_yes
# 24           1          1           0
# 885          1          0           1
# 1163         0          1           0
# ...

# %%
insurance_data.shape
# Out:
# (1338, 10)
